# %% [markdown]
# <a href="https://colab.research.google.com/github/ummijumria1101/FinalProjectTopicsAntenna-TA/blob/main/TACAPSTONE_REVISI2_compare_with_cst_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mengimport package yangn dibutuhkan**

# %%
import pandas as pd
import math as m
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Mengambil data csv dari google drive**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
data = pd.read_csv('/content/drive/MyDrive/TA/materialcoba.csv')
data
# Out:
#       frekuensi   S11real     S11im   S21real     S21im     zreal       zim  \
# 0         1.000 -0.044870  0.040744 -0.910838  0.247148  1.032368  0.241324
# 1         1.004 -0.046218  0.039216 -0.913531  0.237424  1.024299  0.250615
# 2         1.008 -0.047508  0.037632 -0.916145  0.227662  1.015406  0.260158
# 3         1.012 -0.048740  0.035993 -0.918678  0.217861  1.005599  0.269952
# 4         1.016 -0.049910  0.034303 -0.921129  0.208022  0.994778  0.279991
# ...         ...       ...       ...       ...       ...       ...       ...
# 996       4.984 -0.011845 -0.007002 -0.422838  0.887623  0.984691 -0.001483
# 997       4.988 -0.011619 -0.007127 -0.433362  0.882401  0.984752 -0.001550
# 998       4.992 -0.011389 -0.007242 -0.443818  0.877056  0.984817 -0.001612
# 999       4.996 -0.011156 -0.007348 -0.454206  0.871591  0.984885 -0.001672
# 1000      5.000 -0.010920 -0.007442 -0.464523  0.866006  0.984957 -0.001727
#
#       einkreal    einkim      nreal       nim    epsreal      epsim  \
# 0    -0.904403  0.249232  137.06601  3.048040  126.54399 -26.628156
# 1    -0.907034  0.240084  137.00205  3.028045  126.87982 -28.087484
# 2    -0.909624  0.230931  136.93807  3.005435  127.26460 -29.646781
# 3    -0.912176  0.221774  136.87413  2.980109  127.70455 -31.318633
# 4    -0.914692  0.212612  136.81018  2.951934  128.20702 -33.117867
# ...        ...       ...        ...       ...        ...        ...
# 996  -0.422931  0.887673  139.59627  0.161447  141.76595   0.377508
# 997  -0.433454  0.882447  139.59864  0.162499  141.75954   0.388074
# 998  -0.443911  0.877099  139.60096  0.163539  141.75256   0.398136
# 999  -0.454298  0.871630  139.60325  0.164561  141.74503   0.407657
# 1000 -0.464615  0.866042  139.60548  0.165564  141.73696   0.416599
#
#         miureal      miuim
# 0     140.76703  36.224018
# 1     139.57222  37.436444
# 2     138.26583  38.677321
# 3     136.83603  39.946243
# 4     135.26917  41.242170
# ...         ...        ...
# 996   137.45949  -0.048088
# 997   137.47034  -0.056287
# 998   137.48165  -0.064027
# 999   137.49343  -0.071280
# 1000  137.50563  -0.078013
#
# [1001 rows x 15 columns]

# %% [markdown]
# Membuat variabel baru dan memasukkan data S11 dan S21 kedalam array

# %%
#ambil data dari tiap kolom
x_s11 = data.frekuensi
s11real = data.S11real
s11im = data.S11im
s21real= data.S21real
s21im = data.S21im

# %%
#ubah frame ke dalam array
frekuensi = np.array(x_s11)
s11re = np.array(s11real)
s11im = np.array(s11im)
s21re = np.array(s21real)
s21im = np.array(s21im)

# %%
data.iloc[350]
# Out:
# frekuensi      2.400000
# S11real       -0.060927
# S11im         -0.029702
# S21real        0.723255
# S21im          0.571785
# zreal          0.957986
# zim           -0.107033
# einkreal       0.720609
# einkim         0.574318
# nreal        138.291220
# nim            1.625798
# epsreal      142.389110
# epsim         17.605770
# miureal      132.655130
# miuim        -13.244191
# Name: 350, dtype: float64

# %%
#Data N Imaginer perhitungan
plt.plot(frekuensi, s11real, color='violet')
plt.title("KURVA FREKUENSI DAN s11 real", fontsize=10)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('N Imaginer Perhitungan', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
#ubah nilai real dan imaginer kedalam bentuk kompleks
s11=s11re + 1j*s11im
s21=s21re + 1j*s21im

# %% [markdown]
# **MENGHITUNG NILAI EPSILON RELATIF DAN MIU RELATIF**

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)

# %% [markdown]
# ### **Mencari nilai Z**

# %% [markdown]
# **Menghitung nilai impedansi gelombang dari nilai array S11 dan S21**

# %%
#z=impedansi gelombang

a=(((1+s11)**2)-(s21**2))
b=(((1-s11)**2)-(s21**2))
z= (a/b)**0.5
z
# Out:
# array([1.03236825+0.241324j  , 1.02429921+0.25061537j,
#        1.01540585+0.26015837j, ..., 0.98481693-0.00161233j,
#        0.98488508-0.00167155j, 0.98495664-0.00172691j])

# %%
zre=z.real
zre
# Out:
# array([1.03236825, 1.02429921, 1.01540585, ..., 0.98481693, 0.98488508,
#        0.98495664])

# %%
zim=z.imag
zim
# Out:
# array([ 0.241324  ,  0.25061537,  0.26015837, ..., -0.00161233,
#        -0.00167155, -0.00172691])

# %% [markdown]
# **compare data impedansi real (Zreal) dari perhitungan yang sudah didapat dan data Zreal dari CST**

# %% [markdown]
# z real dari perhitungan

# %%
plt.plot(frekuensi, zre, color='violet')
plt.title("KURVA FREKUENSI DAN Z real dari perhitungan", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Z REAL dari perhitungan', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# **Z real dari cst**

# %%
plt.plot(frekuensi, data.zreal, color='violet')
plt.title("KURVA FREKUENSI DAN Z REAL CST", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Z real CST', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# Z imaginer dari perhitungan

# %%
plt.plot(frekuensi, zim, color='violet')
plt.title("KURVA FREKUENSI DAN Z imaginer dari perhitungan", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Z imaginer', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# Z imaginer dari CST

# %%
plt.plot(frekuensi, data.zim, color='violet')
plt.title("KURVA FREKUENSI DAN Z IMAGINER CST", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Z Imaginer CST', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# ### **Mencari nilai E-ink**

# %%
#eink
varA = (z-1)/(z+1)
varB = s11*varA
eink = (s21)/(1-varB)
eink
# Out:
# array([-0.90440277+0.24923154j, -0.90703441+0.2400836j ,
#        -0.90962436+0.23093123j, ..., -0.44391068+0.87709854j,
#        -0.4542984 +0.87162962j, -0.46461545+0.86604151j])

# %%
#Bagi nilai eink real dan imaginer
einkre = eink.real
einkim = eink.imag

# %% [markdown]
# **compare data E-ink dari perhitungan yang sudah didapat dan data E-ink dari CST**

# %%
#Eink perhitungan
plt.plot(frekuensi, einkre, color='violet')
plt.title("KURVA FREKUENSI DAN E-ink real perhitungan", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('eink real perhitungan', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# DATA eink CST

# %%
#E-ink CST
plt.plot(frekuensi, data.einkreal, color='violet')
plt.title("KURVA FREKUENSI DAN eink real cst", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('eink real cst', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# Eink imaginer perhitungan

# %%
#E-ink imag
plt.plot(frekuensi, einkim, color='violet')
plt.title("KURVA FREKUENSI DAN eink imaginer perhitungan", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('eink imaginer perhitungan', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# Eink imaginer CST

# %%
#eink imaginer cst
plt.plot(frekuensi, data.einkim, color='violet')
plt.title("KURVA FREKUENSI DAN eink imaginer cst", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('eink imaginer cst', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# ### **Mencari nilai n**

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)

# %%
#mencari nilai len (eink)
#len eink
ln_e= np.log(eink)
ln_e
# Out:
# array([-0.06388219+2.87269118j, -0.06371698+2.88283592j,
#        -0.06349317+2.89296991j, ..., -0.01711018+2.03932211j,
#        -0.01723091+2.05126429j, -0.01734986+2.06320163j])

# %%
#membagi nilai real dan imaginer dari len eink
lnreal = ln_e.real
lnreal
# Out:
# array([-0.06388219, -0.06371698, -0.06349317, ..., -0.01711018,
#        -0.01723091, -0.01734986])

# %%
lnimag = ln_e.imag
lnimag
# Out:
# array([2.87269118, 2.88283592, 2.89296991, ..., 2.03932211, 2.05126429,
#        2.06320163])

# %%
#m_branch = round( (n_re_KK - real(n_eff)).*k0*d_eff/(2.0*pi) );

# %%
#cari n

m=0
lmda = 300000000/(frekuensi*(10**9)) #meter
k0 = 2*np.pi/(lmda) #konstanta fasanya
eink_len=len(lnimag)
d_mikrostrip = 1/1000 #m
n_re=[0]*eink_len
n_im=[0]*eink_len
def closest(lst, K):

    return lst[min(range(len(lst)), key = lambda i: abs(K-lst[i]))]

for x in range(eink_len):
  nm0=(1/(k0[x]*d_mikrostrip))*((lnimag[x]+2*0*3.14))
  nm1=(1/(k0[x]*d_mikrostrip))*((lnimag[x]+2*1*3.14))
  nm2=(1/(k0[x]*d_mikrostrip))*((lnimag[x]+2*2*3.14))
  nm3=(1/(k0[x]*d_mikrostrip))*((lnimag[x]+2*3*3.14))
  n_im[x]=(1/(k0[x]*d_mikrostrip))*(-1*lnreal[x])
  if x == 0:
    n0=(1/(k0[0]*d_mikrostrip))*((lnimag[0]+2*m*3.14))
    n_re[x]=n0
  else:

    lst = [nm0,nm1,nm2,nm3]
    K = n_re[x-1]
    n_re[x]=closest(lst, K)
print(n_re)
print(n_im)
# Out:
# [137.16090059172836, 137.09690205430826, 137.03287537620446, 136.9688797061177, 136.90489389103143, 136.84086122672548, 136.77681959724248, 136.7126763245126, 136.6484333277719, 136.58400314686182, 136.51936448729498, 136.45445888815325, 136.3892569665327, 136.32371187635286, 136.25783499479664, 136.1917423637732, 136.12557728448746, 136.05979708531535, 135.99509249788653, 135.93274326413672, 135.87488440888458, 135.82499476838902, 135.78752353677103, 135.75465308639625, 138.07150084882622, 137.85920678538406, 137.751983070049, 137.6445677539488, 137.53492584249318, 137.42687565384807, 137.32336113609423, 137.2260399068286, 137.1357947292104, 137.0528515314515, 136.9771246710482, 136.90831921546626, 136.84595194953306, 136.78959726176282, 136.73871660945602, 136.6928563507651, 136.65156752926143, 136.61442379823845, 136.5810662669031, 136.5511309253252, 136.52438391904136, 136.5004757573094, 136.47919206073146, 136.46031408646624, 136.4436458318862, 136.4290220873501, 136.4162665197671, 136.40523624221584, 136.39582186702657, 136.3878659166099, 136.38127846642695, 136.37595120837724, 136.37182105621022,
# %% [markdown]
# COMPARE DATA DENGAN DATA N CST

# %%
#Data N real perhitungan
plt.plot(frekuensi, n_re, color='violet')
plt.title("KURVA FREKUENSI DAN N REAL DARI PERHITUNGAN", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('N REAL DARI PERHITUNGAN', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
#data n real cst
plt.plot(frekuensi, data.nreal, color='violet')
plt.title("KURVA FREKUENSI DAN N REAL CST", fontsize=20)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('N REAL CST', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
#Data N Imaginer perhitungan
plt.plot(frekuensi, n_im, color='violet')
plt.title("KURVA FREKUENSI DAN N IMAGINER PERHITUNGAN", fontsize=10)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('N Imaginer Perhitungan', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
#N IMAGINER CST
plt.plot(frekuensi, data.nim, color='violet')
plt.title("KURVA FREKUENSI DAN N IMAGINER CST", fontsize=14)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('N Imaginer CST', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %% [markdown]
# ### **Mencari nilai epsilon**

# %%
type(n_im)
# Out:
# list

# %%
nre = np.array(n_re)
nim = np.array(n_im)

# %%
#gabung nilai n real dan imaginer
n = nre + 1j*nim

# %%
#digabung
eps = n/z
eps
epsreal = eps.real
epsimag = eps.imag

# %% [markdown]
# ### **Mencari nilai Miu**

# %%
#miu real

miu = n*z
miu
miureal = miu.real
miuimag = miu.imag

# %% [markdown]
# ### **PLOT KURVA**

# %%
plt.plot(frekuensi, epsreal, color='violet')
plt.title("Kurva Epsilon Real dengan Perhitungan", fontsize=16)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Epsilon real', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
plt.plot(frekuensi, data.epsreal, color='violet')
plt.title("Kurva Epsilon Real dari data CST", fontsize=16)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Epsilon real CST', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
data
# Out:
#       frekuensi   S11real     S11im   S21real     S21im     zreal       zim  \
# 0         1.000 -0.044870  0.040744 -0.910838  0.247148  1.032368  0.241324
# 1         1.004 -0.046218  0.039216 -0.913531  0.237424  1.024299  0.250615
# 2         1.008 -0.047508  0.037632 -0.916145  0.227662  1.015406  0.260158
# 3         1.012 -0.048740  0.035993 -0.918678  0.217861  1.005599  0.269952
# 4         1.016 -0.049910  0.034303 -0.921129  0.208022  0.994778  0.279991
# ...         ...       ...       ...       ...       ...       ...       ...
# 996       4.984 -0.011845 -0.007002 -0.422838  0.887623  0.984691 -0.001483
# 997       4.988 -0.011619 -0.007127 -0.433362  0.882401  0.984752 -0.001550
# 998       4.992 -0.011389 -0.007242 -0.443818  0.877056  0.984817 -0.001612
# 999       4.996 -0.011156 -0.007348 -0.454206  0.871591  0.984885 -0.001672
# 1000      5.000 -0.010920 -0.007442 -0.464523  0.866006  0.984957 -0.001727
#
#       einkreal    einkim      nreal       nim    epsreal      epsim  \
# 0    -0.904403  0.249232  137.06601  3.048040  126.54399 -26.628156
# 1    -0.907034  0.240084  137.00205  3.028045  126.87982 -28.087484
# 2    -0.909624  0.230931  136.93807  3.005435  127.26460 -29.646781
# 3    -0.912176  0.221774  136.87413  2.980109  127.70455 -31.318633
# 4    -0.914692  0.212612  136.81018  2.951934  128.20702 -33.117867
# ...        ...       ...        ...       ...        ...        ...
# 996  -0.422931  0.887673  139.59627  0.161447  141.76595   0.377508
# 997  -0.433454  0.882447  139.59864  0.162499  141.75954   0.388074
# 998  -0.443911  0.877099  139.60096  0.163539  141.75256   0.398136
# 999  -0.454298  0.871630  139.60325  0.164561  141.74503   0.407657
# 1000 -0.464615  0.866042  139.60548  0.165564  141.73696   0.416599
#
#         miureal      miuim
# 0     140.76703  36.224018
# 1     139.57222  37.436444
# 2     138.26583  38.677321
# 3     136.83603  39.946243
# 4     135.26917  41.242170
# ...         ...        ...
# 996   137.45949  -0.048088
# 997   137.47034  -0.056287
# 998   137.48165  -0.064027
# 999   137.49343  -0.071280
# 1000  137.50563  -0.078013
#
# [1001 rows x 15 columns]

# %%
plt.plot(frekuensi, epsimag, color='violet')
plt.title("Kurva Epsilon Imaginer dengan Perhitungan", fontsize=16, color='black')
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Epsilon imaginer', fontsize=14, color='black')
plt.grid(True)
plt.show()

# %%
plt.plot(frekuensi, data.epsim, color='violet')
plt.title("Kurva Epsilon Imaginer dari data CST", fontsize=16, color='black')
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Epsilon imaginer CST', fontsize=14, color='black')
plt.grid(True)
plt.show()

# %% [markdown]
# **MIU**

# %%
plt.plot(frekuensi, miureal, color='violet')
plt.title("Kurva Miu Real dengan Perhitungan", fontsize=16)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Miu real', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
plt.plot(frekuensi, data.miureal, color='violet')
plt.title("Kurva Miu Real dari data CST", fontsize=16)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Miu real CST', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
plt.plot(frekuensi, miuimag, color='violet')
plt.title("Kurva Miu Imaginer dengan Perhitungan", fontsize=16)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Miu imaginer', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
plt.plot(frekuensi, data.miuim, color='violet')
plt.title("Kurva Miu Imaginer dari data CST", fontsize=16)
plt.xlabel('Frekuensi', fontsize=14, color='black')
plt.ylabel('Miu imaginer CST', fontsize=14, color='black')
plt.grid (True)
plt.show()

# %%
datacst = pd.DataFrame([*zip(frekuensi, miureal, miuimag, epsreal, epsimag)], columns = ['frekuensi', 'miu_real', 'miu_imag', 'epr_real', 'eps_imag'])
datacst
# Out:
#       frekuensi    miu_real   miu_imag    epr_real   eps_imag
# 0         1.000  140.864484  36.249096  126.631596 -26.646591
# 1         1.004  139.668848  37.462362  126.967660 -28.106930
# 2         1.008  138.361553  38.704098  127.352701 -29.667305
# 3         1.012  136.930756  39.973896  127.792957 -31.340313
# 4         1.016  135.362823  41.270723  128.295783 -33.140796
# ...         ...         ...        ...         ...        ...
# 996       4.984  137.494551  -0.048031  141.802116   0.377676
# 997       4.988  137.505460  -0.056232  141.795757   0.388245
# 998       4.992  137.516824  -0.063973  141.788819   0.398310
# 999       4.996  137.528655  -0.071228  141.781346   0.407834
# 1000      5.000  137.540901  -0.077962  141.773317   0.416779
#
# [1001 rows x 5 columns]

# %%
databatik = datacst.iloc[350]
databatik
# Out:
# frekuensi      2.400000
# miu_real     132.686254
# miu_imag     -13.246577
# epr_real     142.422350
# eps_imag      17.610659
# Name: 350, dtype: float64
